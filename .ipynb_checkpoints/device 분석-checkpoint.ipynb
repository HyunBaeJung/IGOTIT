# %% [markdown]
# Device

# %%
class 소리분류 및 변환기(녹음기):#녹음기 상속. 녹음기로부터 30초 wav파일을 받아온다
    
    def __init__(self,file,detecter):
        super().__init__(file,detecter)
        
    def keras 소리분류(wav파일):
        if self.detecter==1:
            keras모델(wav파일) 로 러닝시키기
            return ({'비명확률': x%,
                     '충돌확률': y%})
        
    def SST변환기(wav파일):
        if self.detecter==1:
            SST데이터=wav파일을 SST로 변환한 최근 30초 데이터
            return SST데이터

class 녹음기:
    
    def __init__(self,file,detecter):
        self.file=file
        self.detecter=detecter
        
    def execute_func(second=1.0):
        global end
        if end:
            return
        self.file=마이크데이터 wav파일로 변환#file라는 변수에 30초단위 wav파일 생성 및 대입
        threading.Timer(second, execute_func, [second]).start()
        
    def __main__():
        while True:
            execute_func(30.0) #30초마다 마이크 데이터를 wav파일로 변환
            if 마이크 데시벨 설정치 초과:#주파수 이상치로 해도 되고 아직 미정
                self.detecter=1
            else:
                self.detecter=0
                
    if __name__ == '__main__':
        main()
    
    
class 상황판단:
    
    soundclassify=소리분류 및 변환기()
    
    def 비명판단(soundclassify.keras 소리분류()):
        if (keras 소리분류(wav파일)['비명확률']>70):
            return ({'비명상황':soundclassify.keras 소리분류()['비명확률']})
        else:
            return ({'비명상황':'비명상황 아님'})
        
    def 충돌판단(soundclassify.keras 소리분류()):
        if (keras 소리분류(wav파일)['충돌확률']>70):
            return ({'충돌상황':soundclassify.keras 소리분류()['충돌확률']})
        else:
            return ({'충돌상황':'충돌상황 아님'})
        
    def GPS이탈판단():
        if GPS가 사전설정된 지역을 벗어났을때:
            return ({'GPS이탈상황':True})
        else:
            return ({'GPS이탈상황':False})
        
    def 사용자지정텍스트판단(soundclassify.SST변환기()):
        if re.search("시라소니",soundclassify.SST변환기()).group(0)=='시라소니':
            return({'사용자지정 위기상황':True})
        else:
            return({'사용자지정 위기상황':False})
    
    def main():
        상황딕셔너리={}
        상황딕셔너리.add({'비명상황' : 비명판단(soundclassify.keras 소리분류())['비명상황']})
        상황딕셔너리.add({'충돌상황' : 비명판단(soundclassify.keras 소리분류())['충돌상황']})
        상황딕셔너리.add({'GPS이탈상황' : 비명판단(soundclassify.keras 소리분류())['GPS이탈상황']})
        상황딕셔너리.add({'사용자지정 위기상황' : 비명판단(soundclassify.keras 소리분류())['사용자지정 위기상황']})
        return(상황딕셔너리)
    
    if __name__ == '__main__':
        main()
        
class 상황대처:
    
    def 상황대처함수():
        if ((상황딕셔너리['비명상황']=!'비명상황 아님')or(상황딕셔너리['충돌상황']=!'충돌상황 아님')or(상황딕셔너리['GPS이탈상황']==True)or(상황딕셔너리['사용자지정 위기상황']==True)):
            상황딕셔너리를 APP으로 전송
        else:
            녹음기() # 위기 상황이 아니면 녹음기 class를 이용해 지속적으로 녹음한다.
